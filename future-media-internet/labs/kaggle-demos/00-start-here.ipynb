# %% [markdown]
# # 🌐 Future Media & Internet
#
# ## Kaggle Hands-on Lab · Start Here
#
# **7 个循序渐进的动手实验｜CPU 可运行｜Internet Off｜无需外部数据集**
#
# > 从网络识别到沉浸式媒体预测：**AI × Network × Media × QoE**

# %% [markdown]
# ## 🧭 学习主线
#
# **Understand → Decide → Measure → Compress → Communicate → Deliver → Predict**
#
# 首次学习建议按 **Demo 1 → Demo 7** 顺序完成。

# %% [markdown]
# ## 🚀 Hands-on Demos
#
# | Demo | 实验入口 | 一句话理解 |
# |---|---|---|
# | **1** | [流量分类 · Traffic Classification](https://www.kaggle.com/code/guopingtan/fmi-demo1-traffic-classification) | 从**端口规则**走向**流量行为 + ML** |
# | **2** | [自适应视频流 · QoE Optimization](https://www.kaggle.com/code/guopingtan/fmi-demo2-qoe-optimization) | 从**固定码率**走向**智能 ABR 决策** |
# | **3** | [视频质量评估 · PSNR vs SSIM](https://www.kaggle.com/code/guopingtan/fmi-demo3-quality-assessment) | 从**像素误差**走向**结构与感知质量** |
# | **4** | [JPEG vs Learned Compression](https://www.kaggle.com/code/guopingtan/fmi-demo4-neural-compression) | 在**相同比特预算**下比较 Rate–Distortion |
# | **5** | [任务导向语义通信](https://www.kaggle.com/code/guopingtan/fmi-demo5-semantic-communication) | 从**完整恢复信号**走向**直接完成任务** |
# | **6** | [网络损伤与视频播放](https://www.kaggle.com/code/guopingtan/fmi-demo-6-network-impairments-on-hd-video) | 从 **Network KPI** 看到 **Buffer 与 Playback QoE** |
# | **7** | [360° / VR Viewport Streaming](https://www.kaggle.com/code/guopingtan/fmi-demo-7-network-impairments-on-vr-360-video) | 从 **Viewport** 走向 **Prediction 与 Foveated Streaming** |

# %% [markdown]
# ## ▶️ 如何开始
#
# **打开任一 Demo → Copy & Edit → Run All**
#
# 主实验统一采用：**CPU · Internet Off · 无需额外 Dataset · 无需 API Key**

# %% [markdown]
# ---
#
# ## 🔗 更多课程与学习资源
#
# [**进入多模态视觉 AI 学习中心 →**](https://multimodal-vision-ai.github.io/multimodal-document-ai-learning-center/)
#
# **课程教程 · 动手实验 · 项目实战 · 论文导读 · 学习资源 · 成果展示**
#
# *MV-AI Lab · Hohai University*
