# %% [markdown]
# # 交通标志目标检测

# %%
from ultralytics import YOLO
import os, random, cv2, matplotlib.pyplot as plt
import cv2
import numpy as np
import torch

# %%
data_yaml = r'D:\AIR\Teaching\Dataset\TrafficSignsDetection\car\data.yaml'  # 数据集配置文件

# %%
yolo_path = r'D:\AIR\Teaching\models\yolov8n.pt'   # 原始yolov8n检测器  

model = YOLO('yolov8n.yaml')
model = YOLO(yolo_path)          # 轻量模型

# %%
import shutil, os
for p in [
    os.path.expanduser('~/.cache/ultralytics'),
    os.path.expanduser('~/.cache/torch/hub/checkpoints'),
    'yolov8n.pt',  # 当前目录
]:
    if os.path.isdir(p):
        shutil.rmtree(p)
    elif os.path.isfile(p):
        os.remove(p)

# %%
import os, shutil, urllib.request

# 手动下载官方完整权重
url = 'https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt'
yolo_path =  r'D:\AIR\Teaching\models\yolov8n.pt'   # 原始yolov8n检测器
urllib.request.urlretrieve(url, yolo_path)
# Out:
# ('D:\\AIR\\Teaching\\models\\yolov8n.pt',
#  <http.client.HTTPMessage at 0x1cebd8c6f90>)

# %%
cache_dir = os.path.expanduser('~/.cache/ultralytics')
if os.path.exists(cache_dir):
    shutil.rmtree(cache_dir)    # 清缓存
    
# 开始训练
train_resluts = model.train(
    data=data_yaml,
    epochs=50,
    imgsz=416,
    batch=16,
    project='yolov8n_tsd',
    device=0
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.170 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.169  Python-3.11.13 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096MiB)
# ...

# %%
train_results = model.train(
    data=tsd_yaml_path, 
    epochs=5,
    patience=5,
    mixup=0.2,
    mosaic=0.5,
    lr0=0.01,
    lrf=0.2,
    batch=16,
    project='yolov8n-tsd',
    #device=0,
)
